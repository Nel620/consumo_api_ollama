# %%
import time
from ollama import Client

client = Client(host='http://api.entornoandres.me')
datos_entrada = "Ventas Q1: $5000, Q2: $7000. Calcula el porcentaje de crecimiento."

# 1. Iniciar cronómetro
inicio = time.time()
print("⏳ Procesando petición...")

# 2. Ejecutar inferencia (Cambia 'llama3' por 'phi3' para comparar)
response = client.chat(model='phi3', messages=[
  {
    'role': 'user',
    'content': f'Actúa como analista de datos. Procesa esto: {datos_entrada}',
  },
])

# 3. Detener cronómetro y calcular
fin = time.time()
tiempo_total = fin - inicio

print(response['message']['content'])
print(f"\n⏱️ Tiempo exacto de ejecución: {tiempo_total:.2f} segundos")
# Out:
# ⏳ Procesando petición...
# Para calcular el porcentaje de crecimiento entre las ventas del primer trimestre (Q1) y el segundo trimestre (Q2), utilizamos la fórmula siguiente: [(Ventas Q2 - Ventas Q1) / Ventas Q1] * 1ner. Sustituimos los valores dados en esta ecuación para encontrar el porcentaje de crecimiento, que es del [($7000-$5000)/$5000]*100% = 40%. Por lo tanto, hubo un aumento del 40% en las ventas entre Q1 y Q2.
#
# ⏱️ Tiempo exacto de ejecución: 34.23 segundos
